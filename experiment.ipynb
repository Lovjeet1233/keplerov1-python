# %%
# !pip install supabase
# Out:
# ...
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# ...
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# ...
#   Attempting uninstall: websockets
#     Found existing installation: websockets 10.4
#     Uninstalling websockets-10.4:
#       Successfully uninstalled websockets-10.4
#   Attempting uninstall: aiosignal
#     Found existing installation: aiosignal 1.3.2
#     Uninstalling aiosignal-1.3.2:
#       Successfully uninstalled aiosignal-1.3.2
#   Attempting uninstall: aiohappyeyeballs
#     Found existing installation: aiohappyeyeballs 2.4.4
#     Uninstalling aiohappyeyeballs-2.4.4:
#       Successfully uninstalled aiohappyeyeballs-2.4.4
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.10.11
#     Uninstalling aiohttp-3.10.11:
#       Successfully uninstalled aiohttp-3.10.11
# ...

# %%
from supabase import create_client, Client

# Your Supabase project URL and API key
url = "https://yqafbhmzphpeaoqkxqqx.supabase.co"  # Replace with your Supabase project URL
key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InlxYWZiaG16cGhwZWFvcWt4cXF4Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3NTM5ODU5NzEsImV4cCI6MjA2OTU2MTk3MX0.mDusCRKyP_XKBrEMexJ1UnseNk2uoE-nj4lHYu96zWA"                     # Use your anon or service_role key

supabase: Client = create_client(url, key)

# %%
response = supabase.table("projects").select("*").execute()

# %%
response
# Out:
# APIResponse[~_ReturnT](data=[], count=None)

# %%
!
!
